# %% [markdown]
# ## **PYTHON BASICS 1**
#
# **Task:** While bitcoin increases 12 per cent a month if I would invest 1000 Turkish liras in bitcoin. At the end, how much money would I have?
# **Solution**

# %%
My_Capital = 1000
Growth = 12
Growth_period = 12
Calculate_Operator = (1 + Growth/100) ** 12
Result = My_Capital*Calculate_Operator
print(Result)
# Out:
# 3895.9759925469807

# %% [markdown]
# **Task:** So, How much money would I earn from this investment?
#
# **Solution**

# %%
My_Earn = Result-My_Capital
print(My_Earn)
# Out:
# 2895.9759925469807

# %% [markdown]
# As a result, I've invested 1000 lira. At the end I have had 3895 lira. On the other hand, I've earned 2895 lira with this investment.
#
# **Task:** Write the solution texts with python.
#
# **Solution**

# %%
print("I've invested", My_Capital, "lira. At the end I have had", Result, "lira. On the other hand, I've earned", My_Earn, "lira with this investment.")
# Out:
# I've invested 1000 lira. At the end I have had 3895.9759925469807 lira. On the other hand, I've earned 2895.9759925469807 lira with this investment.

# %% [markdown]
# **Task:** Write a code that takes name from the user and prints it on the screen by adding py extension to this file name.
#
# **Solution**

# %%
My_code = str(input("File name:"))
print(My_code+".py")
# Out:
# File name:Mali
# Mali.py

# %% [markdown]
# **Taks:** Create a dictionary that includes 7 days of week. Ask the user to select 2 different days by listing the days (for instance "12" for Monday and Tuesday) and print the remaining 5 days by deleting the days that selected by user from the dictionary.
#
# **Solution**

# %%
Days = {1:"monday", 2:"tuesday", 3:"wednesday", 4:"thursday", 5:"friday", 6:"saturday", 7:"sunday"}
deleting_days1 = (input("Chose the numbers of days of week (eg 1 = monday):"))
deleting_days2 = (input("Chose the other day:"))
del Days[int(deleting_days1[0])]
del Days[int(deleting_days2[0])]
print(Days)
# Out:
# Chose the numbers of days of week (eg 1 = monday):1
# Chose the other day:2
# {3: 'wednesday', 4: 'thursday', 5: 'friday', 6: 'saturday', 7: 'sunday'}

# %% [markdown]
# **Task:** We can confuse how many days a month has. For this, create a list, have the names of the months and the numbers of the days together in your list.
# Create another month list that takes the information from the previous list. This time keep the months with the days in the list in two separate lists. Now create seasonal lists. Give the list names the names of the seasons. Finally, calculate how many days the summer lasts from the list in the previous question.
#
# **Solution**

# %%
months_days = [["january", 31], ["february", 28], ["march", 31], ["april", 30], ["may", 31], ["june", 30], ["july", 31], ["august", 31], ["september", 30], ["october", 31], ["november", 30],["december", 31]]
len(months_days)
# Out:
# 12

# %%
spring = months_days[2:5]
summer = months_days[5:8]
autumn = months_days[8:11]
winter = [months_days[11]] + months_days[0:2]

# %%
print(summer)
# Out:
# [['june', 30], ['july', 31], ['august', 31]]

# %%
result = summer[0][1] + summer[1][1] + summer [2][1]
print("sum of summer days:", result)
# Out:
# sum of summer days: 92
